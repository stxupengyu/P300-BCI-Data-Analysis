# %%
#挂载云盘 
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#进入项目目录
print('original document')
# !ls
import os
os.chdir('/content/drive/My Drive/colab/2020年C题')
print('current document')
# !ls
# Out:
# original document
#  2020年C题--面向康复工程的脑电信号分析和判别模型.docx
# '~$20年C题--面向康复工程的脑电信号分析和判别模型.docx'
#  data.rar
#  Untitled0.ipynb
#  附件2-睡眠脑电数据.xlsx
# current document
#  2020年C题--面向康复工程的脑电信号分析和判别模型.docx
# '~$20年C题--面向康复工程的脑电信号分析和判别模型.docx'
#  data.rar
#  Untitled0.ipynb
#  附件2-睡眠脑电数据.xlsx

# %%
# !unrar x data.rar
# Out:
# UNRAR 5.50 freeware      Copyright (c) 1993-2017 Alexander Roshal
#
#
# Extracting from data.rar
#
# Creating    附件1-P300脑机接口数据                                            OK
# Creating    附件1-P300脑机接口数据/S1                                         OK
#   OK
#   OK
#   OK
#   OK
# Creating    附件1-P300脑机接口数据/S2                                         OK
#   OK
#   OK
#   OK
#   OK
# Creating    附件1-P300脑机接口数据/S3                                         OK
#   OK
#   OK
#   OK
#   OK
# Creating    附件1-P300脑机接口数据/S4                                         OK
#   OK
#   OK
#   OK
#   OK
# Creating    附件1-P300脑机接口数据/S5                                         OK
#   OK
#   OK
#   OK
#   OK
# All OK

# %%
#进入项目目录
print('original document')
# !ls
import os
os.chdir('/content/drive/My Drive/colab/2020年E题')
print('current document')
# !ls
# Out:
# original document
#  2020年C题--面向康复工程的脑电信号分析和判别模型.docx
# '~$20年C题--面向康复工程的脑电信号分析和判别模型.docx'
#  data.rar
#  Untitled0.ipynb
#  附件1-P300脑机接口数据
#  附件2-睡眠脑电数据.xlsx
# current document
# 2020年E题--能见度估计与预测.doc  机场视频2	       能见度估计与预测.pdf
# 机场AMOS观测.zip		 能见度估计与预测.doc  高速公路视频截图.zip

# %%
# !unzip 机场AMOS观测.zip
# Out:
# Archive:  机场AMOS观测.zip
#    creating: ╗·│бAMOS╣█▓т/
#    creating: ╗·│бAMOS╣█▓т/AMOS20191216/
#   inflating: ╗·│бAMOS╣█▓т/AMOS20191216/PTU_R06_15.his
#   inflating: ╗·│бAMOS╣█▓т/AMOS20191216/VIS_R06_15.his
#   inflating: ╗·│бAMOS╣█▓т/AMOS20191216/WIND_R06_15.his
#    creating: ╗·│бAMOS╣█▓т/AMOS20200313/
#   inflating: ╗·│бAMOS╣█▓т/AMOS20200313/PTU_R06_12.his
#   inflating: ╗·│бAMOS╣█▓т/AMOS20200313/VIS_R06_12.his
#   inflating: ╗·│бAMOS╣█▓т/AMOS20200313/WIND_R06_12.his
#   inflating: ╗·│бAMOS╣█▓т/AMOS╫╩┴╧╕ё╩╜╦╡├ў .docx
